# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_data(data, filename):
    correct_points = data[data.correct == 1]
    incorrect_points = data[data.correct == 0]
    
    plt.figure(figsize=(10,10))
    plt.scatter(correct_points.x1,correct_points.x2, marker="+")
    plt.scatter(incorrect_points.x1,incorrect_points.x2,marker="x")
    plt.title("Correctly and incorectly classified points", fontsize=16)
    plt.xlabel("x1", fontsize=14)
    plt.ylabel("x2", fontsize=14)
    plt.grid(True)
    plt.savefig(f"output/networks/plots/{filename}")
    plt.show()

# %%
best_model2_data = pd.read_csv("output/networks/prediction_results_model2.csv", names=["x1","x2","correct"])

plot_data(best_model2_data, "accuracy_model2.png")

# %%
best_model3_data = pd.read_csv("output/networks/prediction_results_model3.csv", names=["x1","x2","correct"])
plot_data(best_model3_data, "accuracy_model3.png")

# %%
table_model2 = pd.read_csv("output/networks/model2_parameters_performance.csv")
table_model2
# Out:
#     learning_rate  batch_size  neurons_H1  neurons_h2 activation_H1  \
# 0             0.1          20           4           4          tanh
# 1             0.1          20           4           4          tanh
# 2             0.1          20           4           8          tanh
# 3             0.1          20           4           8          tanh
# 4             0.1          20           4          16          tanh
# 5             0.1          20           4          16          tanh
# 6             0.1          20           8           4          tanh
# 7             0.1          20           8           4          tanh
# 8             0.1          20           8           8          tanh
# 9             0.1          20           8           8          tanh
# 10            0.1          20           8          16          tanh
# 11            0.1          20           8          16          tanh
# 12            0.1          20          16           4          tanh
# 13            0.1          20          16           4          tanh
# 14            0.1          20          16           8          tanh
# 15            0.1          20          16           8          tanh
# 16            0.1          20          16          16          tanh
# 17            0.1          20          16          16          tanh
# 18            0.1         200           4           4          tanh
# 19            0.1         200           4           4          tanh
# 20            0.1         200           4           8          tanh
# 21            0.1         200           4           8          tanh
# 22            0.1         200           4          16          tanh
# 23            0.1         200           4          16          tanh
# 24            0.1         200           8           4          tanh
# 25            0.1         200           8           4          tanh
# 26            0.1         200           8           8          tanh
# 27            0.1         200           8           8          tanh
# 28            0.1         200           8          16          tanh
# 29            0.1         200           8          16          tanh
# 30            0.1         200          16           4          tanh
# 31            0.1         200          16           4          tanh
# 32            0.1         200          16           8          tanh
# 33            0.1         200          16           8          tanh
# 34            0.1         200          16          16          tanh
# 35            0.1         200          16          16          tanh
#
#    activation_H2  accuracy
# 0           tanh   0.70550
# 1           relu   0.55750
# 2           tanh   0.76100
# 3           relu   0.79825
# 4           tanh   0.91125
# 5           relu   0.84650
# 6           tanh   0.75275
# 7           relu   0.73925
# 8           tanh   0.91925
# 9           relu   0.89550
# 10          tanh   0.93550
# 11          relu   0.88225
# 12          tanh   0.82650
# 13          relu   0.78825
# 14          tanh   0.95525
# 15          relu   0.92900
# 16          tanh   0.96200
# 17          relu   0.94150
# 18          tanh   0.66750
# 19          relu   0.65575
# 20          tanh   0.76525
# 21          relu   0.69450
# 22          tanh   0.75950
# 23          relu   0.76575
# 24          tanh   0.75600
# 25          relu   0.78975
# 26          tanh   0.90175
# 27          relu   0.88700
# 28          tanh   0.93400
# 29          relu   0.88225
# 30          tanh   0.75200
# 31          relu   0.80500
# 32          tanh   0.91825
# 33          relu   0.72875
# 34          tanh   0.94375
# 35          relu   0.90225

# %%
# best accuracy for learning rate=0.1, batch=20, activatio=tanh, neurons=16 96% accuracy

# %%
table_model3 = pd.read_csv("output/networks/model3_parameters_performance.csv")
table_model3
# Out:
#      0.1   20   4  4.1  tanh tanh.1   0.7125
# 0    0.1   20   4    4  tanh   relu  0.58875
# 1    0.1   20   4    4  tanh   tanh  0.76950
# 2    0.1   20   4    4  tanh   relu  0.78925
# 3    0.1   20   4    4  tanh   tanh  0.84925
# 4    0.1   20   4    4  tanh   relu  0.80975
# ..   ...  ...  ..  ...   ...    ...      ...
# 102  0.1  200  16   16  tanh   relu  0.83025
# 103  0.1  200  16   16  tanh   tanh  0.96400
# 104  0.1  200  16   16  tanh   relu  0.94100
# 105  0.1  200  16   16  tanh   tanh  0.96250
# 106  0.1  200  16   16  tanh   relu  0.94200
#
# [107 rows x 7 columns]
